# %%
# !pip install bertviz -q

# %%
from transformers import AutoTokenizer, AutoModel, utils

model_name = "Qwen/Qwen2.5-0.5B-Instruct"  # Find popular HuggingFace models here: https://huggingface.co/models

model = AutoModel.from_pretrained(model_name, output_attentions=True)  # Configure model to return attention values
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
from bertviz import model_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

input_text = "What are you doing now?"
inputs = tokenizer.encode(input_text, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model

# %%
outputs.keys()
# Out:
# odict_keys(['last_hidden_state', 'past_key_values', 'attentions'])

# %%
attention = outputs[-1]  # Retrieve attention from model outputs

# %%
for i, attn in enumerate(attention):
    print(f"Layer {i} attention shape: {attn.shape}")
# Out:
# Layer 0 attention shape: torch.Size([1, 14, 6, 6])
# Layer 1 attention shape: torch.Size([1, 14, 6, 6])
# Layer 2 attention shape: torch.Size([1, 14, 6, 6])
# Layer 3 attention shape: torch.Size([1, 14, 6, 6])
# Layer 4 attention shape: torch.Size([1, 14, 6, 6])
# Layer 5 attention shape: torch.Size([1, 14, 6, 6])
# Layer 6 attention shape: torch.Size([1, 14, 6, 6])
# Layer 7 attention shape: torch.Size([1, 14, 6, 6])
# Layer 8 attention shape: torch.Size([1, 14, 6, 6])
# Layer 9 attention shape: torch.Size([1, 14, 6, 6])
# Layer 10 attention shape: torch.Size([1, 14, 6, 6])
# Layer 11 attention shape: torch.Size([1, 14, 6, 6])
# Layer 12 attention shape: torch.Size([1, 14, 6, 6])
# Layer 13 attention shape: torch.Size([1, 14, 6, 6])
# Layer 14 attention shape: torch.Size([1, 14, 6, 6])
# Layer 15 attention shape: torch.Size([1, 14, 6, 6])
# Layer 16 attention shape: torch.Size([1, 14, 6, 6])
# Layer 17 attention shape: torch.Size([1, 14, 6, 6])
# ...

# %%
for i, attn in enumerate(attention):
    print(f"Layer {i} attention weights: {attn}")
# Out:
# Layer 0 attention weights: tensor([[[[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [8.8331e-01, 1.1669e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [7.5585e-01, 1.7140e-01, 7.2748e-02, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [4.3031e-01, 1.8844e-01, 1.7814e-01, 2.0311e-01, 0.0000e+00,
#            0.0000e+00],
#           [3.6116e-01, 1.6790e-01, 1.6805e-01, 1.9300e-01, 1.0988e-01,
#            0.0000e+00],
#           [3.0171e-01, 1.5599e-01, 1.3526e-01, 1.4506e-01, 1.0387e-01,
#            1.5810e-01]],
#
#          [[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [7.9741e-05, 9.9992e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [2.0365e-07, 7.4707e-04, 9.9925e-01, 0.0000e+00, 0.0000e+00,
#            0.0000e+00],
#           [5.8523e-09, 2.4944e-07, 2.4881e-04, 9.9975e-01, 0.0000e+00,
# ...

# %%
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings
model_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-f294ebcdd81b4a2fa3f99434a812a772" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
from bertviz import head_view

head_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-e6c04c476e4a4802b1878ac2889eb895" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
